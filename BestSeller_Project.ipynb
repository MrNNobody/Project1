# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns 
import missingno as mns
# %matplotlib inline

# %%
df= pd.read_csv('bestsellers with categories.csv')
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df.isnull().sum()
# Out:
# Name           0
# Author         0
# User Rating    0
# Reviews        0
# Price          0
# Year           0
# Genre          0
# dtype: int64

# %%
#1.Determine the Percentage  of Fiction and Non-fiction books

# %%
round(100*df['Genre'].value_counts()/len(df['Genre']),2)
# Out:
# Non Fiction    56.36
# Fiction        43.64
# Name: Genre, dtype: float64

# %%
#2.Carry out a research on how question 1 can be represented with graph and plot it

# %%
fig = plt.figure(figsize = (15,10))
rating = df['Genre'].value_counts().plot.pie(autopct = '%1.2f%%')

# %%
#3.Plot a graph showing the number of fiction and non-fiction book by year and state the highest and the lowest year

# %%
sns.countplot (x = df['Year'], hue = df.Genre, data = df)
plt.show()

# %%
#The highest year
#fiction- 2014
#non fiction- 2015

#lowest year
#Fiction- 2015
#Non Fiction- 2014

# %%
#4.Plot a graph showing the distribution of price by genre

# %%
sns.barplot(x= df['Genre'], y= df['Price'], hue=df['Year'], data=df)

# %%
#5.Plot a graph showing the mean price of fiction and non-fiction books by year

# %%
fiction =np.mean(df[df['Genre'] == 'Fiction']['Price'])
fiction_mean = np.mean(fiction)
fiction_mean
# Out:
# 10.85

# %%
fig = plt.figure(figsize = (15,10))
sns.kdeplot(df[df['Genre'] == 'Fiction']['Price'])
plt.show()

# %%
fiction =np.mean(df[df['Genre'] == 'Non Fiction']['Price'])
n_fiction_mean = np.mean(fiction)
n_fiction_mean
# Out:
# 14.841935483870968

# %%
fig = plt.figure(figsize = (15,10))
sns.kdeplot(df[df['Genre'] == 'Non Fiction']['Price'])
plt.show()

# %%
#6.List out the 5 most expensive fiction and non-fiction books in dataframe with the following features(Authur,Name and price)

# %%
EFC = df[df['Genre'] == 'Fiction']
EFC.drop(['User Rating', 'Reviews', 'Year'], axis = 1, inplace = True)
EFC.nlargest(5, ['Price'])
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                                                   Name           Author  \
# 473                       The Twilight Saga Collection  Stephenie Meyer
# 159         Harry Potter Paperback Box Set (Books 1-7)    J. K. Rowling
# 524                                           Watchmen       Alan Moore
# 338                                      The Alchemist     Paulo Coelho
# 108  Fifty Shades Trilogy (Fifty Shades of Grey / F...        E L James
#
#      Price    Genre
# 473     82  Fiction
# 159     52  Fiction
# 524     42  Fiction
# 338     39  Fiction
# 108     32  Fiction

# %%
ENFC = df[df['Genre'] == 'Non Fiction']
ENFC.drop(['User Rating', 'Reviews', 'Year'], axis = 1, inplace = True)
ENFC.nlargest(5, ['Price'])
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                                                   Name  \
# 69   Diagnostic and Statistical Manual of Mental Di...
# 70   Diagnostic and Statistical Manual of Mental Di...
# 151                           Hamilton: The Revolution
# 346  The Book of Basketball: The NBA According to T...
# 271  Publication Manual of the American Psychologic...
#
#                                  Author  Price        Genre
# 69     American Psychiatric Association    105  Non Fiction
# 70     American Psychiatric Association    105  Non Fiction
# 151                  Lin-Manuel Miranda     54  Non Fiction
# 346                        Bill Simmons     53  Non Fiction
# ...

# %%
#7. Determine the percentge of User Rating ang Reviews

# %%
Reviews = round(100*df['Reviews'].value_counts()/len(df['Reviews']),2)
Reviews
# Out:
# 8580     1.82
# 5069     1.64
# 21834    1.45
# 19546    1.27
# 19576    1.09
#          ...
# 3428     0.18
# 14982    0.18
# 9867     0.18
# 13964    0.18
# 2052     0.18
# Name: Reviews, Length: 346, dtype: float64

# %%
Reviews = round(100*df['User Rating'].value_counts()/len(df['User Rating']),2)
Reviews
# Out:
# 4.8    23.09
# 4.7    19.64
# 4.6    19.09
# 4.5    10.91
# 4.9     9.45
# 4.4     6.91
# 4.3     4.55
# 4.0     2.55
# 4.2     1.45
# 4.1     1.09
# 3.9     0.55
# 3.8     0.36
# 3.3     0.18
# 3.6     0.18
# Name: User Rating, dtype: float64

# %%
fig = plt.figure(figsize = (15,10))
rating = df['User Rating'].value_counts().plot.pie(autopct = '%1.2f%%')
